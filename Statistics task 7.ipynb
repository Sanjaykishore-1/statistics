# %%
from scipy import stats
import numpy as np

# %%
7.	Two versions of a website are tested.
Out of 500 users for Version A, 320 users click the signup button.
Out of 480 users for Version B, 290 users click the signup button.
At the 5% level of significance, test whether the conversion rates differ.

 H0 : VA = VB
 HA : VA /= VB

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

successes = np.array([320, 290])
totals = np.array([500, 480])
z_stat, p_value = proportions_ztest(successes, totals, alternative='two-sided')

conv_rate_A = 320 / 500
conv_rate_B = 290 / 480

print(f"Conversion Rate A: {conv_rate_A}")
print(f"Conversion Rate B: {conv_rate_B}")
print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")
# Out:
# Conversion Rate A: 0.64
# Conversion Rate B: 0.6041666666666666
# Z-statistic: 1.1567515462334546
# P-value: 0.24737388327470267

# %%
p_value=p_value/2
p_value
# Out:
# np.float64(0.12368694163735133)

# %%
alpha = 0.05
if p_value > alpha:
    print("Decision: Reject the Null Hypothesis.")
else:
    print("Decision: Fail to Reject the Null Hypothesis.")
# Out:
# Decision: Reject the Null Hypothesis.

# %%
## hence after the comparison of both versions of the website, both that different conversion rate in it, so we reject the Null hypothesis
