# %%
from scipy import stats
import numpy as np

# %%
## 1.  The historical average score in a certification exam is 65.
# A training institute introduces a new course. A random sample of 50 students trained under the new course has an average score of 68.
#At the 5% level of significance, test whether the new course improves performance.

# %%
average_score_50 = np.random.normal(loc=68, scale=10, size=50).astype(int)

# %%
#H0 = 65 
#Ha = 68  of 50 samples
#level of significance = 5% 

average_score_50 = np.random.normal(loc=68, scale=10, size=50).astype(int)
t_stats,p_value = stats.ttest_1samp(a = average_score_50 ,popmean = 65, alternative = "greater")

p_value = p_value/2

if p_value > 0.05:
    print("Fail to reject the null hypothesis")
else:
    print("Reject the null hypothesis")

## answer statement
# Out:
# Reject the null hypothesis

# %% [markdown]
# #### At 5% significance level, we reject the null hypothesis and conclude that the average score of the students is significantly greater than 65.
